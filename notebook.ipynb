# %%
from statsbombpy import sb
events=sb.events(match_id=3890561)
# Out:
# c:\Escritorio\Personal_brand\Data_Science\Portfolio\python_envs\projects_env\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
events
# Out:
#      ball_receipt_outcome ball_recovery_recovery_failure block_deflection  \
# 0                     NaN                            NaN              NaN
# 1                     NaN                            NaN              NaN
# 2                     NaN                            NaN              NaN
# 3                     NaN                            NaN              NaN
# 4                     NaN                            NaN              NaN
# ...                   ...                            ...              ...
# 3935                  NaN                            NaN              NaN
# 3936                  NaN                            NaN              NaN
# 3937                  NaN                            NaN              NaN
# 3938                  NaN                            NaN              NaN
# 3939                  NaN                            NaN              NaN
#
#      carry_end_location clearance_aerial_won clearance_body_part  \
# ...

# %%
events.loc[:100,"timestamp"].values
# Out:
# array(['00:00:00.000', '00:00:00.000', '00:00:00.000', '00:00:00.000',
#        '00:00:00.000', '00:00:00.000', '00:00:00.482', '00:00:01.015',
#        '00:00:02.954', '00:00:05.894', '00:00:10.652', '00:00:14.391',
#        '00:00:17.182', '00:00:19.068', '00:00:20.846', '00:00:28.242',
#        '00:00:33.779', '00:00:36.412', '00:00:39.100', '00:00:42.204',
#        '00:00:46.596', '00:00:50.072', '00:00:53.464', '00:00:54.747',
#        '00:00:59.292', '00:01:01.797', '00:01:05.447', '00:01:06.228',
#        '00:01:07.271', '00:01:08.949', '00:01:11.014', '00:01:13.284',
#        '00:01:16.138', '00:01:18.839', '00:01:19.538', '00:01:21.288',
#        '00:01:25.900', '00:01:28.375', '00:01:29.267', '00:01:30.641',
#        '00:01:32.975', '00:01:34.943', '00:01:38.375', '00:01:41.665',
#        '00:01:43.199', '00:01:56.005', '00:01:58.331', '00:02:00.268',
#        '00:02:16.704', '00:02:22.052', '00:02:25.699', '00:02:28.650',
# ...
